# %% [markdown]
# <div style="background-color:#FFC0CB; padding:40px; text-align:center; border-radius:15px; color:black;">
#
# <h1 style="font-size:40px; margin-bottom:20px; color:black;">
# Práctica 1 - Introducción al uso de Python
# </h1>
#
# <h1 style="font-size:18px; color:black;">
# Laboratorio de Bioseñales <br>
# María Camila Tobón Úsuga
# </h1>
#
# </div>

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas

# %% [markdown]
# # Procedimiento

# %% [markdown]
# a. Creación de vectores a y b.

# %%
a = np.array([3.1,1, -0.5, -3.2, 6])
b = np.array([1, 3, 2.2, 5.1, 1])

# %% [markdown]
# b. Multiplicación escalar de vectores a y b. ¿Qué se debe hacer para implementar la multiplicación de los vectores?
#
# Para poder hacer la multiplicación escalar, o también llamado producto punto de los dos vectores:
#
# Ambos vectores deben de tener la misma longitud,se multiplica elemento a elemento y luego se efectua la suma de los resultados.
#
# Para realizare esta operación se tiene la función np.dot o el operador @ de numpy.

# %%
c = np.dot(a, b)
print(c)
d= a @ b
print (d)
# Out:
# -5.32
# -5.32

# %% [markdown]
# c. Multiplicacion punto a punto a a.b

# %%
e = a * b 
print(e)
# Out:
# [  3.1    3.    -1.1  -16.32   6.  ]

# %% [markdown]
# d. Construcción matriz A.

# %%
A= np.array([(2, -1, -3), (4, 1.5, -2.5), (7.3 , -0.9, 0.2)])

# %% [markdown]
# e. Transpuesta de A.

# %%
f= A.T
print(f)
# Out:
# [[ 2.   4.   7.3]
#  [-1.   1.5 -0.9]
#  [-3.  -2.5  0.2]]

# %% [markdown]
# f. Funciones librería Numpy.
#
# ones --> Devuelve una matriz de forma y tipo determinados, llena de unos.
#
# np.ones(forma, tipo d=Ninguno como float o int, orden='C' para filas ó 'F' para columnas, como=para crear el arreglo con el mismo tipo que otro objeto)

# %%
g = np.ones((3,3), int)
print(g)
# Out:
# [[1 1 1]
#  [1 1 1]
#  [1 1 1]]

# %% [markdown]
# round --> Redondear uniformemente al número dado de decimales.
#
# np.round("a" el arreglo que se quiere modificar, decimales=0 número de deciamales a conservar, fuera= para guardar el resultado en una arreglo ya existente)

# %%
h = np.round(A, 0)
print(h)
# Out:
# [[ 2. -1. -3.]
#  [ 4.  2. -2.]
#  [ 7. -1.  0.]]

# %% [markdown]
# ceil --> Sirve para redondear cada número hacia arriba (al entero mayor más cercano), elemento por elemento.
#
# np.ceil("x" arreglo a modificar, /, fuera=para guardar el resultado en una arreglo ya existente, *, donde=Permite aplicar la función solo en ciertas posiciones ejm x>0, casting='mismo_tipo', orden='K', dtype=Ninguno, subok=Verdadero[, firma]) = <ufunc'ceil'>

# %%
i = np.ceil(A,None)
print(i)
# Out:
# [[ 2. -1. -3.]
#  [ 4.  2. -2.]
#  [ 8. -0.  1.]]

# %% [markdown]
# floor --> Sirve para redondear cada número hacia abajo (al entero menor más cercano), elemento por elemento.
#
# np.floor("x" arreglo a modificar, /, fuera=para guardar el resultado en una arreglo ya existente, *, donde=Permite aplicar la función solo en ciertas posiciones ejm x>0, casting='mismo_tipo', orden='K', dtype=Ninguno, subok=Verdadero[, firma]) = <ufunc'floor'>

# %%
j = np.floor(A,None)
print(j)
# Out:
# [[ 2. -1. -3.]
#  [ 4.  1. -3.]
#  [ 7. -1.  0.]]

# %% [markdown]
# g. Acceso al valor de la primera fila, tercera columna de la matriz A, impresión en consola.

# %%
k = A[0,2]
print(k)
# Out:
# -3.0

# %% [markdown]
# h. Segunda fila de matriz A, impresión en consola.

# %%
l = A[1]
print(l)
# Out:
# [ 4.   1.5 -2.5]

# %% [markdown]
# i. Dimensiones de A.

# %%
m= A.shape
print(m)
# Out:
# (3, 3)

# %% [markdown]
# j. Construcción de función y[n]=sin(π⋅0.12n) intervalo 0 <= n <= 100.

# %%
# Intervalo
n = np.arange(0, 101)
# Señal y[n]
y = np.sin(np.pi * 0.12 * n)

# %% [markdown]
# k. Construcción de función 2[n]=cos(2π⋅0.03n).

# %%
# Señal y2[n]
y2 = np.cos(2 * np.pi * 0.03 * n)

# %% [markdown]
# l. Señales suma y producto
#
# s[n]=y[n]+y2[n]
#
# t[n]=y[n]⋅y2[n]

# %%
s = y + y2
t = y * y2

# %% [markdown]
# m. Graficar y[n] y y2[n] en la misma figura.

# %%
plt.figure()
plt.plot(n, y, color="aquamarine", label='y[n] = sin(pi·0.12n)')
plt.plot(n, y2, color="fuchsia", label='y2[n] = cos(2pi·0.03n)')

plt.xlabel('n')
plt.ylabel('Amplitud')
plt.title('Señales y[n] y y2[n]')
plt.legend(loc='upper right')
plt.grid()

plt.show()

# %% [markdown]
# n. Graficar de s[n] y t[n] en la misma figura.

# %%
plt.figure()
plt.plot(n, s, color="orangered", label='s[n] = y[n] + y2[n]')
plt.plot(n, t, color="green", label='t[n] = y[n] · y2[n]')

plt.xlabel('n')
plt.ylabel('Amplitud')
plt.title('Señales s[n] y t[n]')
plt.legend(loc='upper right')
plt.grid()

plt.show()

# %% [markdown]
# # Repaso PANDAS
